# %% [markdown]
# # Part 2: Regression

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

from itertools import product
from sklearn.preprocessing import LabelEncoder

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from xgboost import XGBRegressor
from xgboost import plot_importance

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
data = pd.read_pickle('data_new.pkl')

# %%
data = data[[
    'date_block_num',
    'shop_id',
    'item_id',
    'item_cnt_month',
    'city_code',
    'item_category_id',
    'type_code',
    'subtype_code',
    'item_cnt_month_lag_1',
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3',
    'item_cnt_month_lag_6',
    #'item_cnt_month_lag_12',
    'date_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_2',
    'date_item_avg_item_cnt_lag_3',
    'date_item_avg_item_cnt_lag_6',
    #'date_item_avg_item_cnt_lag_12',
    'date_shop_avg_item_cnt_lag_1',
    'date_shop_avg_item_cnt_lag_2',
    'date_shop_avg_item_cnt_lag_3',
    'date_shop_avg_item_cnt_lag_6',
    #'date_shop_avg_item_cnt_lag_12',
    'date_cat_avg_item_cnt_lag_1',
    'date_shop_cat_avg_item_cnt_lag_1',
    #'date_shop_type_avg_item_cnt_lag_1',
    #'date_shop_subtype_avg_item_cnt_lag_1',
    'date_city_avg_item_cnt_lag_1',
    'date_item_city_avg_item_cnt_lag_1',
    #'date_type_avg_item_cnt_lag_1',
    #'date_subtype_avg_item_cnt_lag_1',
    'delta_price_lag',
    'month',
    'days',
    'item_shop_last_sale',
    'item_last_sale',
    'item_shop_first_sale',
    'item_first_sale',
]]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del data
#del X_train_lagpart
#del X_test_lagpart
#del X_valid_lagpart
gc.collect();
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8412924 entries, 2262708 to 10675631
# Data columns (total 31 columns):
# date_block_num                       int8
# shop_id                              int8
# item_id                              int16
# city_code                            int8
# item_category_id                     int8
# type_code                            int8
# subtype_code                         int8
# item_cnt_month_lag_1                 float16
# item_cnt_month_lag_2                 float16
# item_cnt_month_lag_3                 float16
# item_cnt_month_lag_6                 float16
# date_avg_item_cnt_lag_1              float16
# date_item_avg_item_cnt_lag_1         float16
# date_item_avg_item_cnt_lag_2         float16
# date_item_avg_item_cnt_lag_3         float16
# date_item_avg_item_cnt_lag_6         float16
# date_shop_avg_item_cnt_lag_1         float16
# date_shop_avg_item_cnt_lag_2         float16
# date_shop_avg_item_cnt_lag_3         float16
# date_shop_avg_item_cnt_lag_6         float16
# date_cat_avg_item_cnt_lag_1          float16
# date_shop_cat_avg_item_cnt_lag_1     float16
# date_city_avg_item_cnt_lag_1         float16
# date_item_city_avg_item_cnt_lag_1    float16
# delta_price_lag                      float16
# month                                int8
# days                                 int8
# item_shop_last_sale                  int8
# item_last_sale                       int8
# item_shop_first_sale                 int8
# item_first_sale                      int8
# dtypes: float16(18), int16(1), int8(12)
# memory usage: 465.3 MB

# %%
ts = time.time()

model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse",     eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)

time.time() - ts
# Out:
# [0]	validation_0-rmse:1.18636	validation_1-rmse:1.11894
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.13928	validation_1-rmse:1.08197
# [2]	validation_0-rmse:1.1002	validation_1-rmse:1.05277
# [3]	validation_0-rmse:1.06591	validation_1-rmse:1.02671
# [4]	validation_0-rmse:1.03654	validation_1-rmse:1.00617
# [5]	validation_0-rmse:1.01156	validation_1-rmse:0.989469
# [6]	validation_0-rmse:0.990985	validation_1-rmse:0.975477
# [7]	validation_0-rmse:0.973188	validation_1-rmse:0.963227
# [8]	validation_0-rmse:0.957764	validation_1-rmse:0.954722
# [9]	validation_0-rmse:0.944243	validation_1-rmse:0.947554
# [10]	validation_0-rmse:0.933859	validation_1-rmse:0.941637
# [11]	validation_0-rmse:0.925372	validation_1-rmse:0.937056
# [12]	validation_0-rmse:0.917243	validation_1-rmse:0.932606
# [13]	validation_0-rmse:0.910197	validation_1-rmse:0.928466
# [14]	validation_0-rmse:0.904512	validation_1-rmse:0.924696
# [15]	validation_0-rmse:0.898665	validation_1-rmse:0.920589
# [16]	validation_0-rmse:0.894087	validation_1-rmse:0.91855
# [17]	validation_0-rmse:0.89066	validation_1-rmse:0.91756
# [18]	validation_0-rmse:0.887237	validation_1-rmse:0.916959
# [19]	validation_0-rmse:0.88391	validation_1-rmse:0.915647
# [20]	validation_0-rmse:0.88039	validation_1-rmse:0.914692
# [21]	validation_0-rmse:0.877553	validation_1-rmse:0.913303
# [22]	validation_0-rmse:0.875344	validation_1-rmse:0.91245
# [23]	validation_0-rmse:0.87306	validation_1-rmse:0.911937
# [24]	validation_0-rmse:0.871203	validation_1-rmse:0.911515
# [25]	validation_0-rmse:0.869708	validation_1-rmse:0.911413
# [26]	validation_0-rmse:0.868083	validation_1-rmse:0.911069
# [27]	validation_0-rmse:0.866454	validation_1-rmse:0.911219
# [28]	validation_0-rmse:0.864851	validation_1-rmse:0.911185
# [29]	validation_0-rmse:0.86386	validation_1-rmse:0.91103
# [30]	validation_0-rmse:0.862319	validation_1-rmse:0.910286
# [31]	validation_0-rmse:0.861051	validation_1-rmse:0.909748
# [32]	validation_0-rmse:0.859686	validation_1-rmse:0.909287
# [33]	validation_0-rmse:0.858656	validation_1-rmse:0.909549
# [34]	validation_0-rmse:0.857735	validation_1-rmse:0.908999
# [35]	validation_0-rmse:0.856553	validation_1-rmse:0.908258
# [36]	validation_0-rmse:0.855776	validation_1-rmse:0.907705
# [37]	validation_0-rmse:0.854991	validation_1-rmse:0.907791
# [38]	validation_0-rmse:0.85425	validation_1-rmse:0.907919
# [39]	validation_0-rmse:0.853514	validation_1-rmse:0.908441
# [40]	validation_0-rmse:0.852876	validation_1-rmse:0.908653
# [41]	validation_0-rmse:0.852142	validation_1-rmse:0.908539
# [42]	validation_0-rmse:0.851643	validation_1-rmse:0.908207
# [43]	validation_0-rmse:0.850988	validation_1-rmse:0.907903
# [44]	validation_0-rmse:0.850383	validation_1-rmse:0.907736
# [45]	validation_0-rmse:0.849638	validation_1-rmse:0.907604
# [46]	validation_0-rmse:0.84915	validation_1-rmse:0.907783
# [47]	validation_0-rmse:0.848318	validation_1-rmse:0.907573
# [48]	validation_0-rmse:0.847951	validation_1-rmse:0.90755
# [49]	validation_0-rmse:0.847523	validation_1-rmse:0.907632
# [50]	validation_0-rmse:0.847035	validation_1-rmse:0.907779
# [51]	validation_0-rmse:0.846717	validation_1-rmse:0.907746
# [52]	validation_0-rmse:0.846375	validation_1-rmse:0.908184
# [53]	validation_0-rmse:0.845986	validation_1-rmse:0.908125
# [54]	validation_0-rmse:0.845626	validation_1-rmse:0.90794
# [55]	validation_0-rmse:0.845219	validation_1-rmse:0.907884
# [56]	validation_0-rmse:0.844856	validation_1-rmse:0.907687
# [57]	validation_0-rmse:0.844416	validation_1-rmse:0.9075
# [58]	validation_0-rmse:0.843961	validation_1-rmse:0.907809
# [59]	validation_0-rmse:0.843618	validation_1-rmse:0.907963
# [60]	validation_0-rmse:0.843217	validation_1-rmse:0.907927
# [61]	validation_0-rmse:0.843019	validation_1-rmse:0.907806
# [62]	validation_0-rmse:0.842778	validation_1-rmse:0.907726
# [63]	validation_0-rmse:0.842476	validation_1-rmse:0.907449
# [64]	validation_0-rmse:0.842257	validation_1-rmse:0.907443
# [65]	validation_0-rmse:0.841862	validation_1-rmse:0.907251
# [66]	validation_0-rmse:0.841561	validation_1-rmse:0.907164
# [67]	validation_0-rmse:0.840996	validation_1-rmse:0.906833
# [68]	validation_0-rmse:0.84067	validation_1-rmse:0.906779
# [69]	validation_0-rmse:0.840281	validation_1-rmse:0.90715
# [70]	validation_0-rmse:0.839539	validation_1-rmse:0.907005
# [71]	validation_0-rmse:0.83934	validation_1-rmse:0.906968
# [72]	validation_0-rmse:0.838919	validation_1-rmse:0.90703
# [73]	validation_0-rmse:0.838664	validation_1-rmse:0.906995
# [74]	validation_0-rmse:0.838409	validation_1-rmse:0.906855
# [75]	validation_0-rmse:0.837874	validation_1-rmse:0.907076
# [76]	validation_0-rmse:0.837619	validation_1-rmse:0.907181
# [77]	validation_0-rmse:0.837392	validation_1-rmse:0.90727
# [78]	validation_0-rmse:0.83721	validation_1-rmse:0.907408
# Stopping. Best iteration:
# [68]	validation_0-rmse:0.84067	validation_1-rmse:0.906779
# 1292.9762001037598

# %%
test  = pd.read_csv('input/test.csv').set_index('ID')

Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission_new4.csv', index=False)

# save predictions for an ensemble
pickle.dump(Y_pred, open('xgb_train.pickle_new4', 'wb'))
pickle.dump(Y_test, open('xgb_test.pickle_new4', 'wb'))

# %%
plot_features(model, (10,14))

# %%
del X_train
del Y_train
del X_valid
del Y_valid
del X_test
del Y_test
gc.collect()
# Out:
# 19

# %% [markdown]
#  # End
