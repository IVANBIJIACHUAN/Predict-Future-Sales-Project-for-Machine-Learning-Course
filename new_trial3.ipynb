# %% [markdown]
# # Part 2: Regression

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

from itertools import product
from sklearn.preprocessing import LabelEncoder

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from xgboost import XGBRegressor
from xgboost import plot_importance

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
data = pd.read_pickle('data_new.pkl')

# %%
data = data[[
    'date_block_num',
    'shop_id',
    'item_id',
    'item_cnt_month',
    'city_code',
    'item_category_id',
    'type_code',
    'subtype_code',
    'item_cnt_month_lag_1',
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3',
    'item_cnt_month_lag_6',
    #'item_cnt_month_lag_12',
    'date_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_2',
    'date_item_avg_item_cnt_lag_3',
    'date_item_avg_item_cnt_lag_6',
    #'date_item_avg_item_cnt_lag_12',
    'date_shop_avg_item_cnt_lag_1',
    'date_shop_avg_item_cnt_lag_2',
    'date_shop_avg_item_cnt_lag_3',
    'date_shop_avg_item_cnt_lag_6',
    #'date_shop_avg_item_cnt_lag_12',
    'date_cat_avg_item_cnt_lag_1',
    'date_shop_cat_avg_item_cnt_lag_1',
    #'date_shop_type_avg_item_cnt_lag_1',
    #'date_shop_subtype_avg_item_cnt_lag_1',
    'date_city_avg_item_cnt_lag_1',
    'date_item_city_avg_item_cnt_lag_1',
    #'date_type_avg_item_cnt_lag_1',
    #'date_subtype_avg_item_cnt_lag_1',
    'delta_price_lag',
    'month',
    'days',
    'item_shop_last_sale',
    'item_last_sale',
    'item_shop_first_sale',
    'item_first_sale',
]]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del data
#del X_train_lagpart
#del X_test_lagpart
#del X_valid_lagpart
gc.collect();
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8412924 entries, 2262708 to 10675631
# Data columns (total 31 columns):
# date_block_num                       int8
# shop_id                              int8
# item_id                              int16
# city_code                            int8
# item_category_id                     int8
# type_code                            int8
# subtype_code                         int8
# item_cnt_month_lag_1                 float16
# item_cnt_month_lag_2                 float16
# item_cnt_month_lag_3                 float16
# item_cnt_month_lag_6                 float16
# date_avg_item_cnt_lag_1              float16
# date_item_avg_item_cnt_lag_1         float16
# date_item_avg_item_cnt_lag_2         float16
# date_item_avg_item_cnt_lag_3         float16
# date_item_avg_item_cnt_lag_6         float16
# date_shop_avg_item_cnt_lag_1         float16
# date_shop_avg_item_cnt_lag_2         float16
# date_shop_avg_item_cnt_lag_3         float16
# date_shop_avg_item_cnt_lag_6         float16
# date_cat_avg_item_cnt_lag_1          float16
# date_shop_cat_avg_item_cnt_lag_1     float16
# date_city_avg_item_cnt_lag_1         float16
# date_item_city_avg_item_cnt_lag_1    float16
# delta_price_lag                      float16
# month                                int8
# days                                 int8
# item_shop_last_sale                  int8
# item_last_sale                       int8
# item_shop_first_sale                 int8
# item_first_sale                      int8
# dtypes: float16(18), int16(1), int8(12)
# memory usage: 465.3 MB

# %%
ts = time.time()

model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=200, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.2,    
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse",     eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)

time.time() - ts
# Out:
# [0]	validation_0-rmse:1.18626	validation_1-rmse:1.11903
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.13912	validation_1-rmse:1.08166
# [2]	validation_0-rmse:1.09986	validation_1-rmse:1.05222
# [3]	validation_0-rmse:1.06546	validation_1-rmse:1.02637
# [4]	validation_0-rmse:1.0359	validation_1-rmse:1.00505
# [5]	validation_0-rmse:1.01088	validation_1-rmse:0.988145
# [6]	validation_0-rmse:0.990252	validation_1-rmse:0.97432
# [7]	validation_0-rmse:0.972461	validation_1-rmse:0.962294
# [8]	validation_0-rmse:0.956984	validation_1-rmse:0.953974
# [9]	validation_0-rmse:0.943554	validation_1-rmse:0.946692
# [10]	validation_0-rmse:0.933109	validation_1-rmse:0.940652
# [11]	validation_0-rmse:0.924521	validation_1-rmse:0.936114
# [12]	validation_0-rmse:0.916223	validation_1-rmse:0.932222
# [13]	validation_0-rmse:0.909152	validation_1-rmse:0.928092
# [14]	validation_0-rmse:0.903389	validation_1-rmse:0.92413
# [15]	validation_0-rmse:0.89779	validation_1-rmse:0.92287
# [16]	validation_0-rmse:0.892516	validation_1-rmse:0.920299
# [17]	validation_0-rmse:0.888997	validation_1-rmse:0.919355
# [18]	validation_0-rmse:0.885553	validation_1-rmse:0.91875
# [19]	validation_0-rmse:0.882132	validation_1-rmse:0.91762
# [20]	validation_0-rmse:0.879001	validation_1-rmse:0.916159
# [21]	validation_0-rmse:0.875969	validation_1-rmse:0.915138
# [22]	validation_0-rmse:0.873578	validation_1-rmse:0.913654
# [23]	validation_0-rmse:0.871253	validation_1-rmse:0.912202
# [24]	validation_0-rmse:0.86938	validation_1-rmse:0.91195
# [25]	validation_0-rmse:0.867721	validation_1-rmse:0.911988
# [26]	validation_0-rmse:0.866149	validation_1-rmse:0.911351
# [27]	validation_0-rmse:0.864335	validation_1-rmse:0.910569
# [28]	validation_0-rmse:0.862844	validation_1-rmse:0.910733
# [29]	validation_0-rmse:0.86139	validation_1-rmse:0.91011
# [30]	validation_0-rmse:0.85933	validation_1-rmse:0.90843
# [31]	validation_0-rmse:0.858174	validation_1-rmse:0.908242
# [32]	validation_0-rmse:0.856829	validation_1-rmse:0.908203
# [33]	validation_0-rmse:0.855835	validation_1-rmse:0.908333
# [34]	validation_0-rmse:0.85477	validation_1-rmse:0.907972
# [35]	validation_0-rmse:0.85372	validation_1-rmse:0.907343
# [36]	validation_0-rmse:0.853081	validation_1-rmse:0.907328
# [37]	validation_0-rmse:0.852448	validation_1-rmse:0.907348
# [38]	validation_0-rmse:0.851246	validation_1-rmse:0.907555
# [39]	validation_0-rmse:0.85066	validation_1-rmse:0.907644
# [40]	validation_0-rmse:0.849947	validation_1-rmse:0.907685
# [41]	validation_0-rmse:0.849191	validation_1-rmse:0.907514
# [42]	validation_0-rmse:0.848483	validation_1-rmse:0.907388
# [43]	validation_0-rmse:0.847743	validation_1-rmse:0.907323
# [44]	validation_0-rmse:0.847175	validation_1-rmse:0.907491
# [45]	validation_0-rmse:0.846634	validation_1-rmse:0.907373
# [46]	validation_0-rmse:0.846198	validation_1-rmse:0.907366
# [47]	validation_0-rmse:0.845719	validation_1-rmse:0.907437
# [48]	validation_0-rmse:0.845283	validation_1-rmse:0.907668
# [49]	validation_0-rmse:0.844783	validation_1-rmse:0.907351
# [50]	validation_0-rmse:0.844325	validation_1-rmse:0.90747
# [51]	validation_0-rmse:0.843978	validation_1-rmse:0.907202
# [52]	validation_0-rmse:0.843376	validation_1-rmse:0.907008
# [53]	validation_0-rmse:0.842828	validation_1-rmse:0.907021
# [54]	validation_0-rmse:0.842382	validation_1-rmse:0.906941
# [55]	validation_0-rmse:0.841936	validation_1-rmse:0.906871
# [56]	validation_0-rmse:0.841578	validation_1-rmse:0.907026
# [57]	validation_0-rmse:0.841071	validation_1-rmse:0.906709
# [58]	validation_0-rmse:0.84033	validation_1-rmse:0.90682
# [59]	validation_0-rmse:0.839884	validation_1-rmse:0.90722
# [60]	validation_0-rmse:0.8396	validation_1-rmse:0.907269
# [61]	validation_0-rmse:0.839283	validation_1-rmse:0.907391
# [62]	validation_0-rmse:0.838952	validation_1-rmse:0.907423
# [63]	validation_0-rmse:0.838265	validation_1-rmse:0.906161
# [64]	validation_0-rmse:0.837994	validation_1-rmse:0.906073
# [65]	validation_0-rmse:0.837655	validation_1-rmse:0.905932
# [66]	validation_0-rmse:0.837025	validation_1-rmse:0.907526
# [67]	validation_0-rmse:0.836581	validation_1-rmse:0.90754
# [68]	validation_0-rmse:0.836251	validation_1-rmse:0.907721
# [69]	validation_0-rmse:0.83577	validation_1-rmse:0.907848
# [70]	validation_0-rmse:0.835571	validation_1-rmse:0.907738
# [71]	validation_0-rmse:0.835301	validation_1-rmse:0.907852
# [72]	validation_0-rmse:0.835101	validation_1-rmse:0.907913
# [73]	validation_0-rmse:0.834788	validation_1-rmse:0.908087
# [74]	validation_0-rmse:0.83454	validation_1-rmse:0.907872
# [75]	validation_0-rmse:0.834216	validation_1-rmse:0.908085
# Stopping. Best iteration:
# [65]	validation_0-rmse:0.837655	validation_1-rmse:0.905932
# 1441.7818841934204

# %%
test  = pd.read_csv('input/test.csv').set_index('ID')

Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission_new3.csv', index=False)

# save predictions for an ensemble
pickle.dump(Y_pred, open('xgb_train.pickle_new3', 'wb'))
pickle.dump(Y_test, open('xgb_test.pickle_new3', 'wb'))

# %%
plot_features(model, (10,14))

# %%
del X_train
del Y_train
del X_valid
del Y_valid
del X_test
del Y_test
gc.collect()
# Out:
# 34

# %% [markdown]
#  # End
